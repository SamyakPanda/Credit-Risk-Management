# %%
''' Import numpy, pandas, sklearn modules and libraries'''
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.decomposition import PCA 
from catboost import CatBoostClassifier
# Classification metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import cohen_kappa_score
# Ignore ConvergenceWarning messages
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter(action='ignore')
from functools import reduce
from sklearn.preprocessing import LabelEncoder

# %%
def train_application():
    """
    This function reads application_train.csv table, cleans it and perform manual feature engineering for each
    application (SK_ID_CURR).   
    
    Parameters:
    None

    Returns:
    train :   train DataFrame which includes hand engineered features from 
                  just application_train table.   
    
    """

    print('Processing application_train and application_test tables')
    train = pd.read_csv('application_train.csv')
    # Delete four applications with XNA CODE_GENDER (train set)
    train = train[train['CODE_GENDER'] != 'XNA']
    # Replace DAYS_EMPLOYED = 365243 by nan
    train['DAYS_EMPLOYED'].replace({365243: np.nan}, inplace = True) 
    # Feature engineering
    train['Days_employed_age']   = train['DAYS_EMPLOYED'] / train['DAYS_BIRTH']
    train['Credit_income_ratio'] = train['AMT_CREDIT'] / train['AMT_INCOME_TOTAL']
    train['Anuity_income_ratio'] = train['AMT_ANNUITY'] / train['AMT_INCOME_TOTAL'] 
    train['Income_per_person']   = train['AMT_INCOME_TOTAL'] / train['CNT_FAM_MEMBERS']
    #length of the payment in months since the annuity is the monthly amount due
    train['Credit_term'] = train['AMT_ANNUITY']/train['AMT_CREDIT'] 
    return train

# %%
def bureau_journey():
    """
    This function reads bureau.csv and burea_balance.csv tables which includes the recorded
    ID of previous credit bureau (SK_ID_BUREAU), hand engineered new features, and 
    returns the statiscs related to each application SK_ID_CURR.

    Parameters:
    None

    Returns:
    stats: pandas DataFrame including bureau related statistics for each SK_ID_CURR.  
    """

    print('Processing bureau and bureau balance tables...')
    bureau = pd.read_csv('bureau.csv')
    # ------------------------------------Feature Engineering (1): General ------------------------------------------
    bureau['Days_early_paidoff'] =  bureau['DAYS_CREDIT_ENDDATE'] - bureau['DAYS_ENDDATE_FACT']
    bureau['Duration_real']      = bureau['DAYS_ENDDATE_FACT'] - bureau['DAYS_CREDIT']
    bureau['Duration_planned']   = bureau['DAYS_CREDIT_ENDDATE'] - bureau['DAYS_CREDIT'] 
    #Replace data with Duration_planned = 0 with 1 to avoide devision by zero
    bureau['Duration_planned'].replace({0: 1}, inplace = True) 
    # Weighted sum of credit a person borrowed (per days) 
    bureau['AMT_weightdebt_duration'] = bureau['AMT_CREDIT_SUM_DEBT'] / bureau['Duration_planned']
    # 'AMT_CREDIT_SUM_OVERDUE': Current amount overdue on credit 
    bureau['AMT_Overdue_duration'] = bureau['AMT_CREDIT_SUM_OVERDUE'] / bureau['Duration_planned'] 
    # Maximal amount overdue so far 
    bureau['AMT_Maxoverdue_duration'] = bureau['AMT_CREDIT_MAX_OVERDUE']/bureau['Duration_planned'] 
    # Defaulted: CREDIT_DAY_OVERDUE > 270 days is considered defaluted
    bureau['Defaulted'] = np.where(bureau['CREDIT_DAY_OVERDUE'] > 270, 1, 0)
    bureau['AMT_defaulted'] = bureau['Defaulted']*bureau['AMT_CREDIT_SUM_DEBT']
    # Encoding CREDIT_ACTIVE ('Closed','Active') to (0,1)
    mapping = {'Closed':0, 'Active': 1}
    bureau['CREDIT_ACTIVE'] = bureau['CREDIT_ACTIVE'].map(mapping)
    # Flatten manual features with aggregations 
    stats = bureau.sort_values('DAYS_CREDIT', ascending = False).groupby('SK_ID_CURR') \
          .agg({'AMT_CREDIT_SUM_DEBT': ['count' ,'sum', 'mean'], 
                'AMT_weightdebt_duration': ['sum', 'mean'], 
                'AMT_Overdue_duration': [ 'sum', 'mean'], 
                'AMT_Maxoverdue_duration': ['mean'], 
                'Days_early_paidoff': [ 'sum', 'mean'],
                'Defaulted':[ 'sum', 'mean'], 
                'AMT_defaulted':[ 'sum', 'mean'],
                'CREDIT_ACTIVE': 'sum'}) 
    stats.columns = stats.columns.map('_'.join)
    # Flatten last four stats for each applicant (nth() method does not work with .agg method)
    columns = ['SK_ID_CURR', 'DAYS_CREDIT', 'AMT_CREDIT_SUM_DEBT', 'AMT_weightdebt_duration', 'AMT_Overdue_duration', \
              'Days_early_paidoff','Defaulted', 'AMT_defaulted'] 
    stats0  = bureau.sort_values('DAYS_CREDIT', ascending = False)[columns].groupby('SK_ID_CURR').nth(0) 
    stats1  = bureau.sort_values('DAYS_CREDIT', ascending = False)[columns].groupby('SK_ID_CURR').nth(1)
    stats2  = bureau.sort_values('DAYS_CREDIT', ascending = False)[columns].groupby('SK_ID_CURR').nth(2)
    stats3  = bureau.sort_values('DAYS_CREDIT', ascending = False)[columns].groupby('SK_ID_CURR').nth(3)
    data_frames = [stats0, stats1, stats2, stats3]
    lags = reduce(lambda  left,right: pd.concat( [left,right], axis=1, sort= False), data_frames)
    col=[]
    for i in range(4):
        col += ['DAYS_CREDIT'+str(i), 'AMT_CREDIT_SUM_DEBT'+ str(i), 'AMT_weightdebt_duration'+ str(i), \
                'AMT_Overdue_duration'+ str(i), 'Days_early_paidoff'+ str(i),'Defaulted'+ str(i), 'AMT_defaulted'+ str(i)] 
    lags.columns = col  
    stats = pd.merge(stats, lags, on= 'SK_ID_CURR', how ='outer')
    #--------------------------- Feature Engineering (2): Loan cycle life for different CREDIT_TYPE------------------------------
    # Select 6 categories of loans with the highest frequency 
    filter = (bureau['CREDIT_TYPE'] == 'Mortgage')  | (bureau['CREDIT_TYPE'] == 'Real estate loan') \
              | (bureau['CREDIT_TYPE'] == 'Car loan') \
              | (bureau['CREDIT_TYPE'] == 'Loan for business development') \
              | (bureau['CREDIT_TYPE'] == 'Loan for the purchase of equipment') \
              | (bureau['CREDIT_TYPE'] == 'Cash loan (non-earmarked)')\
              | (bureau['CREDIT_TYPE'] == 'Loan for working capital replenishment')  
    btype = bureau[filter].copy()
    # first(DAYS_CREDIT) is when the last credit of each credit type applied and last(DAYS_CREDIT) is when the first onces applied.
    bt_stats  = btype.sort_values('DAYS_CREDIT', ascending = False).groupby(['SK_ID_CURR','CREDIT_TYPE'])\
               .agg({ 'DAYS_CREDIT': ['first', 'last'], 'AMT_CREDIT_SUM_DEBT': ['count', 'sum', 'mean'],\
                      'CREDIT_ACTIVE': 'sum' ,'Defaulted':'sum', 'AMT_defaulted':['sum']})
    bt_stats.columns = bt_stats.columns.map('_'.join)
    mortgage = bt_stats[bt_stats.index.isin(['Mortgage'], level='CREDIT_TYPE')]
    mortgage.index = mortgage.index.droplevel('CREDIT_TYPE')
    realestate = bt_stats[bt_stats.index.isin(['Real estate loan'], level='CREDIT_TYPE')]
    realestate.index = realestate.index.droplevel('CREDIT_TYPE')
    carloan = bt_stats[bt_stats.index.isin(['Car loan'], level='CREDIT_TYPE')]
    carloan.index = carloan.index.droplevel('CREDIT_TYPE')
    loanbusiness = bt_stats[bt_stats.index.isin(['Loan for business development'], level='CREDIT_TYPE')]
    loanbusiness.index = loanbusiness.index.droplevel('CREDIT_TYPE')
    loanpurchase = bt_stats[bt_stats.index.isin(['Loan for the purchase of equipment'], level='CREDIT_TYPE')]
    loanpurchase.index = loanpurchase.index.droplevel('CREDIT_TYPE')
    cashloan = bt_stats[bt_stats.index.isin(['Cash loan (non-earmarked)'], level='CREDIT_TYPE')]
    cashloan.index = cashloan.index.droplevel('CREDIT_TYPE')
    workingloan = bt_stats[bt_stats.index.isin(['Loan for working capital replenishment'], level='CREDIT_TYPE')]
    workingloan.index = workingloan.index.droplevel('CREDIT_TYPE')
    dataframes = [mortgage, realestate, carloan, loanbusiness, loanpurchase, cashloan, workingloan]
    credit_type = reduce(lambda left, right: pd.merge(left,right, on = 'SK_ID_CURR', how= 'outer'), dataframes)
    types = ['mortgage', 'realestate', 'carloan', 'loanbusiness', 'loanpurchase', 'cashloan', 'workingloan']
    columns =[]
    for s in types:
        columns += ['DAYS_CREDIT_first_' + s,  'DAYS_CREDIT_last_' + s , 'AMT_CREDIT_SUM_DEBT_count_'+ s,   \
                    'AMT_CREDIT_SUM_DEBT_sum_' + s , 'AMT_CREDIT_SUM_DEBT_mean_' + s ,   \
                    'CREDIT_ACTIVE_sum_x_' + s , 'Defaulted_sum_x_' + s , 'AMT_defaulted_sum_' + s]
    credit_type.columns = columns
    stats.merge(credit_type, on ='SK_ID_CURR', how= 'outer')
    #-----------------------------Feature Engineering (3): Loan cycle life for Credit Card----------------------------------------
    ccdebt_bureau = bureau[bureau['CREDIT_TYPE'] == 'Credit card'].sort_values('DAYS_CREDIT', ascending = False)\
                          .groupby('SK_ID_CURR').agg({'AMT_CREDIT_SUM_DEBT':['count','sum', 'mean', 'first']})
    ccdebt_bureau.columns = ccdebt_bureau.columns.map('_'.join)
    stats = stats.merge(ccdebt_bureau, on= 'SK_ID_CURR', how = 'outer')
    #------------------------------Feature Engineering (4): Bureau Balance Table---------------------------------------------------
    bureaubal = pd.read_csv('bureau_balance.csv')
    # When did the credit closed? When was the last delinquency for each bureau credit?
    # Last close is obtained by first 0 in MONTHS_BALANCE, last delinquency is obtained from first 1.
    bbalance = bureaubal.groupby(['SK_ID_BUREAU','STATUS'], as_index=False).first()
    left  = bbalance[(bbalance['STATUS'] == '0')][['SK_ID_BUREAU','MONTHS_BALANCE']]
    right = bbalance[(bbalance['STATUS'] == '1')][['SK_ID_BUREAU','MONTHS_BALANCE']]
    bbalance = pd.merge(left,right, on= 'SK_ID_BUREAU', how='left')
    bbalance.columns = ['SK_ID_BUREAU','Months_latest_open','Months_latest_delin']
    # Delinquency ratios: how often each bureau delayed? 
    delinquency = pd.get_dummies(bureaubal[(bureaubal['STATUS'] != 'X') & (bureaubal['STATUS'] != 'C')])
    delinquency = delinquency.groupby('SK_ID_BUREAU').agg({'STATUS_0':'mean','STATUS_1':'mean','STATUS_2':'mean','STATUS_3':'mean',
                                                     'STATUS_4':'mean','STATUS_5':'mean'}) 
    bbalance = bbalance.merge(delinquency, on='SK_ID_BUREAU', how = 'inner')
    # Add SK_ID_CURR to bbalance dataframe
    bbalance = bureau[['SK_ID_CURR','SK_ID_BUREAU']].merge(bbalance, on = 'SK_ID_BUREAU', how= 'inner')
    # pick the latest open SK_ID_Bureau 
    bbalance = bbalance.sort_values('Months_latest_open', ascending= False).groupby('SK_ID_CURR').first()
    # merge with stats
    stats = stats.merge(bbalance, on ='SK_ID_CURR', how='outer')
    return stats

# %%
def homecredit_prv_app():
    """
    This function reads previous_application.csv which includes the recorded
    ID of previous credit at Home Credit company (SK_ID_PREV), hand engineered new features, and 
    returns the statiscs related to each application SK_ID_CURR.

    Parameters:
    None

    Returns:
    prev1: pandas DataFrame having statistics related to previous loans for each SK_ID_CURR at Home Credit.  
    """

    print('Processing previous application tables at Home Credit....')
    prev = pd.read_csv('previous_application.csv')
    #------------------------------Feature Engineering (1): General ---------------------------
    # When was the last application applied and contract status?
    prev1 = prev.sort_values('DAYS_DECISION', ascending = False).\
                 groupby(['SK_ID_CURR']).agg({'DAYS_DECISION':'first', 'NAME_CONTRACT_STATUS': 'first', 'AMT_CREDIT' : 'first'})
    # last credit amount, interest rates, ... the most recent approved 
    df = prev[prev['NAME_CONTRACT_STATUS'] == 'Approved'] \
                  .sort_values('DAYS_DECISION', ascending = False).groupby('SK_ID_CURR').first()
    df = df[['NAME_CONTRACT_TYPE', 'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT',
                  'NAME_YIELD_GROUP','NFLAG_INSURED_ON_APPROVAL','RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED']]
    df['Diff_applied_apprved'] = df['AMT_APPLICATION'] - df['AMT_CREDIT']
    prev1 = prev1.merge(df , on='SK_ID_CURR', how= 'outer')
    #--------------------Feature Engineering (2): Ratioss of Approved Refused Canceled and Unused offer for each application-----------
    df = prev.groupby(['SK_ID_CURR','NAME_CONTRACT_STATUS']).agg({'SK_ID_PREV':'count'})
    df = df.groupby(level='SK_ID_CURR').apply(lambda x: x/x.sum())
    approved = df[df.index.isin(['Approved'], level='NAME_CONTRACT_STATUS')]['SK_ID_PREV']
    approved.index = approved.index.droplevel('NAME_CONTRACT_STATUS')
    refused  = df[df.index.isin(['Refused'], level='NAME_CONTRACT_STATUS')]['SK_ID_PREV']
    refused.index = refused.index.droplevel('NAME_CONTRACT_STATUS')
    canceled = df[df.index.isin(['Canceled'], level='NAME_CONTRACT_STATUS')]['SK_ID_PREV']
    canceled.index = canceled.index.droplevel('NAME_CONTRACT_STATUS')
    unused   = df[df.index.isin(['Unused offer'], level='NAME_CONTRACT_STATUS')]['SK_ID_PREV']
    unused.index = unused.index.droplevel('NAME_CONTRACT_STATUS')
    data_frames = [approved,refused,canceled,unused]
    df = reduce(lambda  left,right: pd.merge( left,right, on = 'SK_ID_CURR', how='outer'), data_frames)
    df.columns = ['ratio_approved','ratio_refused','ratio_canceled', 'ratio_unused']
    prev1 = prev1.merge(df, on='SK_ID_CURR', how= 'outer')
    #--------------------Feature Engineering (3): Latest credit time and amount for the approved different NAME_CONTRACT_TYPE -------------
    df = prev[prev['NAME_CONTRACT_STATUS'] == 'Approved'].sort_values('DAYS_DECISION', ascending = False).\
                 groupby(['SK_ID_CURR','NAME_CONTRACT_TYPE']).agg({'DAYS_DECISION':'first', 'AMT_CREDIT' : 'first'})
    consumer_loans = df[df.index.isin(['Consumer loans'], level='NAME_CONTRACT_TYPE')][['DAYS_DECISION','AMT_CREDIT']]
    consumer_loans.index = consumer_loans.index.droplevel('NAME_CONTRACT_TYPE')
    cash_loans = df[df.index.isin(['Cash loans'], level='NAME_CONTRACT_TYPE')][['DAYS_DECISION','AMT_CREDIT']]
    cash_loans.index = cash_loans.index.droplevel('NAME_CONTRACT_TYPE')
    revolving_loans = df[df.index.isin(['Revolving loans'], level='NAME_CONTRACT_TYPE')][['DAYS_DECISION','AMT_CREDIT']]
    revolving_loans.index = revolving_loans.index.droplevel('NAME_CONTRACT_TYPE')
    dfs = [consumer_loans,cash_loans, revolving_loans]
    df = reduce(lambda left,right: pd.merge(left,right, on ='SK_ID_CURR', how = 'outer'), dfs )
    df.columns = ['Days_consumerloans', 'AMT_credit_consumerloans', 'Days_cashloans','AMT_credit_cashloans',
                        'Days_revolvingloans','AMT_credit_revolvingloans']
    prev1 = prev1.merge(df, on='SK_ID_CURR', how= 'outer') 
    return prev1

# %%
def homecredit_cc():
    """
    This function reads credit_card_balance.csv having recorded
    ID of previous credit card at Home Credit company (SK_ID_PREV), 
    hand engineered new features, and returns the statiscs related to each application SK_ID_CURR.

    Parameters:
    None

    Returns:
    stats: pandas DataFrame having statistics related to previous credit card for each SK_ID_CURR at Home Credit.  
    """

    ccb = pd.read_csv('credit_card_balance.csv')
    ccb['Beyond_limit'] = np.where(ccb['AMT_BALANCE'] > ccb['AMT_CREDIT_LIMIT_ACTUAL'] , 1, 0)
    ccb['Delinquent'] = np.where(ccb['AMT_PAYMENT_CURRENT'] < ccb['AMT_INST_MIN_REGULARITY'] , 1, 0)
    # Percentage change of credit card balance between two successive months
    def pct_diff(group):
      group['balance_pct_change'] = group['AMT_BALANCE'].diff()/(group['AMT_BALANCE'].shift(1)+1)
      group['balance_pct_change'] = np.where(group['balance_pct_change'] > 30, 30, group['balance_pct_change'])
      return group
    ccb = ccb.sort_values('MONTHS_BALANCE').groupby('SK_ID_PREV').apply(pct_diff)    
    # how many times credit card reached 80% and above?
    ccb['times_bal80'] = np.where(ccb['AMT_BALANCE']/ccb['AMT_CREDIT_LIMIT_ACTUAL'] >= 0.8, 1, 0)
    # How many credit card do applicant have at the moment? What is the total balance on them? (outstanding debt of credit card)
    ccb['has_cc_now'] = np.where(ccb['MONTHS_BALANCE'] == -1 , 1 , 0 )
    ccb['balance_now'] = ccb['has_cc_now'] * ccb['AMT_BALANCE'] 
    stats = ccb.groupby('SK_ID_CURR', as_index=False).agg({'has_cc_now': 'sum', 'balance_now': 'sum', 'times_bal80': 'sum'})
    # Flatten last four months balance and percentage change for each applicant
    cols = ['MONTHS_BALANCE','Beyond_limit','Delinquent','balance_pct_change']
    cclast = ccb.sort_values('MONTHS_BALANCE', ascending = False).groupby(['SK_ID_CURR'])[cols].nth(0)
    cclag1 = ccb.sort_values('MONTHS_BALANCE', ascending = False).groupby(['SK_ID_CURR'])[cols].nth(1)
    cclag2 = ccb.sort_values('MONTHS_BALANCE', ascending = False).groupby(['SK_ID_CURR'])[cols].nth(2)
    cclag3 = ccb.sort_values('MONTHS_BALANCE', ascending = False).groupby(['SK_ID_CURR'])[cols].nth(3)
    dfs = [cclast, cclag1, cclag2, cclag3]
    lags = reduce(lambda left,right: pd.concat([left,right], axis=1, sort= False), dfs)
    columns = []
    for i in range(4):
        columns += ['MONTHS_BALANCE'+str(i), 'Beyond_limit'+str(i),'Delinquent'+str(i), 'balance_pct_change'+str(i)]
    lags.columns = columns
    stats = stats.merge(lags, on='SK_ID_CURR', how= 'outer')
    return stats

# %%
def installment():
    """
    This function reads installments_payments.csv having recorded
    ID of previous installment payment at Home Credit company (SK_ID_PREV), 
    hand engineered new features, and returns the statiscs related to each application SK_ID_CURR.

    Parameters:
    None

    Returns:
    stats: pandas DataFrame having statistics related to previous installment for each SK_ID_CURR at Home Credit.
    """

    insta = pd.read_csv('installments_payments.csv')
    # 'DAYS_INSTALMENT': days before credit card supposed to be paid, 'DAYS_ENTRY_PAYMENT': days that amount was acutually paid
    insta['insta_delinquency'] = np.where(insta['DAYS_INSTALMENT'] >= insta['DAYS_ENTRY_PAYMENT'], 0, 1)
    insta['insta_debt'] = insta['AMT_INSTALMENT'] - insta['AMT_PAYMENT']
    stats = insta.sort_values('DAYS_INSTALMENT', ascending = False).groupby(['SK_ID_CURR']).agg({'DAYS_INSTALMENT':'first','insta_debt': ['sum', 'mean', 'first'], 'insta_delinquency' :['sum','first']})
    stats.columns = stats.columns.map('_'.join)
    return stats

# %%
def pos_cash():
    """
    This function reads POS_CASH_balance.csv having recorded
    ID of previous point of sale (POS) transaction for each Home Credit company credit (SK_ID_PREV), 
    hand engineered new features, and returns the statiscs related to each application SK_ID_CURR.

    Parameters:
    None

    Returns:
    poslag: pandas DataFrame having statistics related to previous POS for each SK_ID_CURR at Home Credit.
    """

    pc = pd.read_csv('POS_CASH_balance.csv')
    # Flatten all the columns for the latest 4 POS data for each application 
    pc = pc.sort_values('MONTHS_BALANCE', ascending = False)
    cols = ['MONTHS_BALANCE','SK_DPD','SK_DPD_DEF']
    pos0 = pc.groupby(['SK_ID_CURR'])[cols].first()
    pos1 = pc.groupby(['SK_ID_CURR'])[cols].nth(1)
    pos2 = pc.groupby(['SK_ID_CURR'])[cols].nth(2)
    pos3 = pc.groupby(['SK_ID_CURR'])[cols].nth(3)
    data_frames = [pos0, pos1, pos2, pos3]
    poslag = reduce(lambda  left,right: pd.concat( [left,right], axis=1, sort= False), data_frames)
    columns =[]
    for i in range(4):
        columns += ['MONTHS_BALANCE' + str(i), 'SK_DPD'+ str(i),'SK_DPD_DEF'+ str(i) ]
    poslag.columns = columns
    return poslag

# %%
def merge_tables():
    ''' 
    This function merges the hand-engineered features obtained from bureau and home credit company with
    the main application for training dataset

    Parameters:
    None

    Returns:
    train:  train DataFrame which includes hand engineered features from 
                  all tables including main application, bureau, and previous Home Credit tables.  

    '''

    prev_home   = homecredit_prv_app()
    prev_home   = prev_home.merge(homecredit_cc(), on='SK_ID_CURR', how= 'outer')
    prev_home   = prev_home.merge(installment(), on='SK_ID_CURR', how= 'outer')
    prev_home   = prev_home.merge(pos_cash(), on='SK_ID_CURR', how= 'outer')
    train       = train_application()
    train       = train.merge(bureau_journey(), on='SK_ID_CURR', how='left')
    train       = train.merge(prev_home, on='SK_ID_CURR', how='left')
    return train

# %%
def preprocessing(train):
    '''
    This function calculates the correlation between all features in training data and drops the columns with 
    correlation > 0.98. Then, it encodes categorical features and save them as 'category' type for lightGBM algorithms.

    Parameters:
    train: trainig table after merging all the tables.

    Returns:
    train: train pandas.DataFrame which includes preprocessed training dataset.
    '''

    print('Preprocessing final table and label encoding categorical features...')
    # Drop the columns with correlation > 0.98
    corr = train.corr()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
    to_drop = [column for column in upper.columns if any(upper[column] > 0.98)]
    train = train.drop(to_drop, axis=1)
    # Encoding categorical features because Catboost offers good accuracy with integer-encoded categorical features. 
    class_le = LabelEncoder()
    cols = train.select_dtypes(include= object).columns
    for col in cols:
        train[col] = class_le.fit_transform(train[col].values.astype(str))
        train[col] = train[col].astype('category')
    return train

# %%
def CatBoost(train, num_folds, test_size):
    '''
    This function trains a machine learning model using Catboost algorithm. 
    The boosted algorithm hyper parameters was found using Bayasian optimization.

    Parameters:
    train: preprocessed dataframes 
    num_folds: number of folds for cross-validation (default is 5)
    test_size: ratio of test to train in the training dataset

    Returns:
    pred_class: Binary class prediction of the target variable.
    pred: Probability prediction of the target variable.
    y_test: y_test in the training dataset
    '''

    print('Applying CatBoost algorithm...')
    y = train['TARGET']
    X = train.drop('TARGET', axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = test_size, random_state=1234)
    
    pipeline = Pipeline(steps = [('sc', StandardScaler()),('catboost', CatBoostClassifier())])
    params = {
        "catboost__depth": [5, 6],
        "catboost__iterations": [500, 1000],
        "catboost__learning_rate": [0.001, 0.01, 0.1], 
        "catboost__l2_leaf_reg": [5, 100]
    }
  
    model = RandomizedSearchCV(pipeline, params, n_iter=4, scoring='roc_auc', cv=5, n_jobs=-1, verbose = 3)
    model.fit(X_train, y_train)

    # Binary class prediction
    pred_class = model.predict(X_test)
    # Probability prediction
    pred = model.predict_proba(X_test)
    pred = [p[1] for p in pred]

    return pred_class, pred, y_test

# %%
def calculate_metrics(pred_class, pred, y_test):
    '''
    This function calculates the classificaiton metrics including precision, recall, F1-Score, AUC_ROC, and cohen-kappa coefficient.

    Parameters:
    pred_class: Binary class prediction of the target variable.
    pred: Probability prediction of the target variable.
    y_test: y_test in the trainig dataset

    Returns:
    None
    '''

    # ROC_AUC score
    print('ROC_AUC:', roc_auc_score(y_test, pred))
    # Precision/Recall (0.1 Threshold)
    pred_class_2 = (np.array(pred) > 0.1).astype(int)
    cm = confusion_matrix(y_test, pred_class_2)
    print('\nConfusion_metrix (0.1 Threshold): \n', cm)
    # True Negatives (TN)
    tn = cm[0][0]
    # False Positives (FP)
    fp = cm[0][1]    
    # False Negatives (FN)
    fn = cm[1][0]
    # True Positives (TP)
    tp = cm[1][1]
    precision = tp / (tp + fp)
    print( 'Precision (0.1 Threshold): ', precision )
    recall = tp / (tp + fn)
    print( 'Recall (0.1 Threshold): ', recall )
    print( 'F1-score ( 0.1 Threshold):', 2*precision*recall/(precision+recall))
    cohen_kappa = cohen_kappa_score(y_test, pred_class_2)
    print( '\nCohen_kappa (0.1 Threshold): ', cohen_kappa )

# %%
def plot_ROC(y_test, pred):
    '''
    This function plots ROC based on y_test and predictied probability of positive class by lightGBM.

    Parameters:
    pred: Probability prediction of the target variable.
    y_test: y_test in the trainig dataset

    Returns:
    None
    '''

    # Initialize figure
    fig = plt.figure(figsize=(9,9))
    plt.title('Receiver Operating Characteristic')
    # Plot ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, pred)
    plt.plot(fpr, tpr)
    # Diagonal 45 degree line
    plt.plot([0,1],[0,1],'k--')
    # Axes limits and labels
    plt.xlim([-0.1,1.1])
    plt.ylim([-0.1,1.1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
def plot_precision_recall(y_test, pred):
    '''
    This function plots precicision_recall curve based on y_test and predictied probability of positive class by lightGBM..

    Parameters:
    pred: Probability prediction of the target variable.
    y_test: y_test in the trainig dataset
    
    Returns:
    None
    '''

    precision, recall, thresholds = precision_recall_curve(y_test, pred)
    fig = plt.figure(figsize=(9,9))
    plt.title('Precision_Recall')
    # Plot Precision-Recall curve
    plt.plot(recall, precision)
    # Axes limits and labels
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel('Precision')
    plt.xlabel('Recall')
    plt.show()

# %%
train = pd.read_csv('application_train.csv')

# %%
train.shape
# Out:
# (307511, 122)

# %%
# Select the first 10,000 rows
train = train.iloc[:10000]

# %%
''' -------------------------------Main---------------------------
The main calls all funcitons sequentillay, merge the tables, train CatBoost, and plot the classification metrics.
'''

# Cleaning, feature engineering, and flattening of data from bureau and HomeCredit 
# and merging the application_train 
# train = merge_tables()
# Preprocesing including label encoding of categorical varibles for CatBoost
train = preprocessing(train)
# Training Catboost
nfolds = 3
test_size = 0.05
pred_class, pred, y_test = CatBoost(train, nfolds, test_size)
# Evalutate ROC_AUC, Precision, Recall, F1-Score, Kohen-Cappa metrics
calculate_metrics(pred_class, pred, y_test)
# Plot ROC curve
plot_ROC(y_test, pred)
# Plot Precision/R curve
plot_precision_recall(y_test, pred)
# Out:
# Preprocessing final table and label encoding categorical features...
# Applying CatBoost algorithm...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# 0:	learn: 0.6828927	total: 160ms	remaining: 1m 19s
# 1:	learn: 0.6731565	total: 181ms	remaining: 45.2s
# 2:	learn: 0.6635376	total: 200ms	remaining: 33.1s
# 3:	learn: 0.6536194	total: 217ms	remaining: 26.9s
# 4:	learn: 0.6442536	total: 232ms	remaining: 23s
# 5:	learn: 0.6351259	total: 248ms	remaining: 20.4s
# 6:	learn: 0.6262713	total: 265ms	remaining: 18.6s
# 7:	learn: 0.6176329	total: 289ms	remaining: 17.8s
# 8:	learn: 0.6095480	total: 306ms	remaining: 16.7s
# 9:	learn: 0.6012340	total: 324ms	remaining: 15.9s
# 10:	learn: 0.5931160	total: 336ms	remaining: 14.9s
# 11:	learn: 0.5851662	total: 349ms	remaining: 14.2s
# 12:	learn: 0.5773262	total: 362ms	remaining: 13.6s
# 13:	learn: 0.5697554	total: 378ms	remaining: 13.1s
# 14:	learn: 0.5627132	total: 406ms	remaining: 13.1s
# 15:	learn: 0.5556552	total: 421ms	remaining: 12.7s
# 16:	learn: 0.5487220	total: 435ms	remaining: 12.4s
# 17:	learn: 0.5421443	total: 450ms	remaining: 12s
# 18:	learn: 0.5354915	total: 468ms	remaining: 11.9s
# 19:	learn: 0.5291985	total: 481ms	remaining: 11.5s
# 20:	learn: 0.5231565	total: 496ms	remaining: 11.3s
# 21:	learn: 0.5169510	total: 503ms	remaining: 10.9s
# 22:	learn: 0.5107297	total: 509ms	remaining: 10.6s
# 23:	learn: 0.5049389	total: 517ms	remaining: 10.3s
# 24:	learn: 0.4993442	total: 528ms	remaining: 10s
# 25:	learn: 0.4938803	total: 537ms	remaining: 9.79s
# 26:	learn: 0.4879812	total: 547ms	remaining: 9.59s
# 27:	learn: 0.4827308	total: 557ms	remaining: 9.39s
# 28:	learn: 0.4774630	total: 566ms	remaining: 9.19s
# 29:	learn: 0.4725703	total: 576ms	remaining: 9.03s
# 30:	learn: 0.4672791	total: 585ms	remaining: 8.86s
# 31:	learn: 0.4626088	total: 596ms	remaining: 8.71s
# 32:	learn: 0.4579129	total: 607ms	remaining: 8.59s
# 33:	learn: 0.4533517	total: 618ms	remaining: 8.46s
# 34:	learn: 0.4481961	total: 634ms	remaining: 8.42s
# 35:	learn: 0.4436808	total: 647ms	remaining: 8.34s
# 36:	learn: 0.4397011	total: 661ms	remaining: 8.27s
# 37:	learn: 0.4357245	total: 688ms	remaining: 8.37s
# 38:	learn: 0.4316425	total: 704ms	remaining: 8.31s
# 39:	learn: 0.4278361	total: 715ms	remaining: 8.22s
# 40:	learn: 0.4242379	total: 728ms	remaining: 8.15s
# 41:	learn: 0.4201384	total: 739ms	remaining: 8.06s
# 42:	learn: 0.4163814	total: 749ms	remaining: 7.96s
# 43:	learn: 0.4130592	total: 759ms	remaining: 7.87s
# 44:	learn: 0.4095321	total: 769ms	remaining: 7.77s
# 45:	learn: 0.4059340	total: 777ms	remaining: 7.67s
# 46:	learn: 0.4026134	total: 788ms	remaining: 7.59s
# 47:	learn: 0.3993380	total: 798ms	remaining: 7.51s
# 48:	learn: 0.3960467	total: 808ms	remaining: 7.44s
# 49:	learn: 0.3930544	total: 819ms	remaining: 7.37s
# 50:	learn: 0.3894694	total: 827ms	remaining: 7.28s
# 51:	learn: 0.3865777	total: 838ms	remaining: 7.22s
# 52:	learn: 0.3835083	total: 847ms	remaining: 7.14s
# 53:	learn: 0.3808574	total: 857ms	remaining: 7.08s
# 54:	learn: 0.3781805	total: 866ms	remaining: 7s
# 55:	learn: 0.3755410	total: 874ms	remaining: 6.93s
# 56:	learn: 0.3730653	total: 885ms	remaining: 6.88s
# 57:	learn: 0.3705651	total: 896ms	remaining: 6.83s
# 58:	learn: 0.3682154	total: 909ms	remaining: 6.79s
# 59:	learn: 0.3658875	total: 922ms	remaining: 6.76s
# 60:	learn: 0.3634143	total: 935ms	remaining: 6.73s
# 61:	learn: 0.3610417	total: 947ms	remaining: 6.69s
# 62:	learn: 0.3585693	total: 960ms	remaining: 6.66s
# 63:	learn: 0.3563127	total: 975ms	remaining: 6.64s
# 64:	learn: 0.3536284	total: 989ms	remaining: 6.62s
# 65:	learn: 0.3516044	total: 1s	remaining: 6.61s
# 66:	learn: 0.3490883	total: 1.02s	remaining: 6.63s
# 67:	learn: 0.3471788	total: 1.04s	remaining: 6.63s
# 68:	learn: 0.3454076	total: 1.06s	remaining: 6.6s
# 69:	learn: 0.3436052	total: 1.07s	remaining: 6.56s
# 70:	learn: 0.3415794	total: 1.08s	remaining: 6.53s
# 71:	learn: 0.3397489	total: 1.1s	remaining: 6.51s
# 72:	learn: 0.3379895	total: 1.11s	remaining: 6.5s
# 73:	learn: 0.3361736	total: 1.13s	remaining: 6.5s
# 74:	learn: 0.3343773	total: 1.15s	remaining: 6.49s
# 75:	learn: 0.3328259	total: 1.16s	remaining: 6.48s
# 76:	learn: 0.3312391	total: 1.18s	remaining: 6.47s
# 77:	learn: 0.3294276	total: 1.2s	remaining: 6.48s
# 78:	learn: 0.3277303	total: 1.21s	remaining: 6.47s
# 79:	learn: 0.3262756	total: 1.23s	remaining: 6.45s
# 80:	learn: 0.3249103	total: 1.25s	remaining: 6.46s
# 81:	learn: 0.3235777	total: 1.26s	remaining: 6.43s
# 82:	learn: 0.3220450	total: 1.27s	remaining: 6.41s
# 83:	learn: 0.3205969	total: 1.29s	remaining: 6.38s
# 84:	learn: 0.3191634	total: 1.3s	remaining: 6.35s
# 85:	learn: 0.3177184	total: 1.31s	remaining: 6.33s
# 86:	learn: 0.3163060	total: 1.33s	remaining: 6.3s
# 87:	learn: 0.3147955	total: 1.34s	remaining: 6.27s
# 88:	learn: 0.3134034	total: 1.35s	remaining: 6.23s
# 89:	learn: 0.3122725	total: 1.36s	remaining: 6.18s
# 90:	learn: 0.3110823	total: 1.36s	remaining: 6.13s
# 91:	learn: 0.3100329	total: 1.37s	remaining: 6.09s
# 92:	learn: 0.3088543	total: 1.39s	remaining: 6.06s
# 93:	learn: 0.3077992	total: 1.4s	remaining: 6.03s
# 94:	learn: 0.3066925	total: 1.41s	remaining: 5.99s
# 95:	learn: 0.3055907	total: 1.41s	remaining: 5.95s
# 96:	learn: 0.3046820	total: 1.43s	remaining: 5.92s
# 97:	learn: 0.3037225	total: 1.44s	remaining: 5.9s
# 98:	learn: 0.3025007	total: 1.45s	remaining: 5.88s
# 99:	learn: 0.3017237	total: 1.46s	remaining: 5.86s
# 100:	learn: 0.3006440	total: 1.48s	remaining: 5.83s
# 101:	learn: 0.2997231	total: 1.49s	remaining: 5.81s
# 102:	learn: 0.2987584	total: 1.5s	remaining: 5.78s
# 103:	learn: 0.2978508	total: 1.51s	remaining: 5.76s
# 104:	learn: 0.2970569	total: 1.52s	remaining: 5.73s
# 105:	learn: 0.2960574	total: 1.54s	remaining: 5.72s
# 106:	learn: 0.2952807	total: 1.55s	remaining: 5.7s
# 107:	learn: 0.2944266	total: 1.56s	remaining: 5.67s
# 108:	learn: 0.2934621	total: 1.57s	remaining: 5.65s
# 109:	learn: 0.2926077	total: 1.58s	remaining: 5.62s
# 110:	learn: 0.2917521	total: 1.6s	remaining: 5.6s
# 111:	learn: 0.2908319	total: 1.61s	remaining: 5.58s
# 112:	learn: 0.2900133	total: 1.63s	remaining: 5.57s
# 113:	learn: 0.2892957	total: 1.64s	remaining: 5.56s
# 114:	learn: 0.2885255	total: 1.66s	remaining: 5.55s
# 115:	learn: 0.2876919	total: 1.68s	remaining: 5.56s
# 116:	learn: 0.2870153	total: 1.7s	remaining: 5.56s
# 117:	learn: 0.2864321	total: 1.71s	remaining: 5.55s
# 118:	learn: 0.2857617	total: 1.73s	remaining: 5.53s
# 119:	learn: 0.2849215	total: 1.74s	remaining: 5.5s
# 120:	learn: 0.2842226	total: 1.75s	remaining: 5.47s
# 121:	learn: 0.2834809	total: 1.76s	remaining: 5.44s
# 122:	learn: 0.2827821	total: 1.76s	remaining: 5.41s
# 123:	learn: 0.2821657	total: 1.77s	remaining: 5.38s
# 124:	learn: 0.2815152	total: 1.78s	remaining: 5.35s
# 125:	learn: 0.2809941	total: 1.79s	remaining: 5.32s
# 126:	learn: 0.2804986	total: 1.8s	remaining: 5.29s
# 127:	learn: 0.2798935	total: 1.81s	remaining: 5.27s
# 128:	learn: 0.2792894	total: 1.82s	remaining: 5.25s
# 129:	learn: 0.2786108	total: 1.84s	remaining: 5.23s
# 130:	learn: 0.2780390	total: 1.85s	remaining: 5.2s
# 131:	learn: 0.2774272	total: 1.86s	remaining: 5.18s
# 132:	learn: 0.2767649	total: 1.87s	remaining: 5.16s
# 133:	learn: 0.2762404	total: 1.88s	remaining: 5.14s
# 134:	learn: 0.2757193	total: 1.9s	remaining: 5.15s
# 135:	learn: 0.2751985	total: 1.92s	remaining: 5.13s
# 136:	learn: 0.2747517	total: 1.93s	remaining: 5.1s
# 137:	learn: 0.2741737	total: 1.94s	remaining: 5.08s
# 138:	learn: 0.2737364	total: 1.95s	remaining: 5.05s
# 139:	learn: 0.2732597	total: 1.96s	remaining: 5.03s
# 140:	learn: 0.2727875	total: 1.97s	remaining: 5.01s
# 141:	learn: 0.2722976	total: 1.98s	remaining: 4.99s
# 142:	learn: 0.2718490	total: 1.99s	remaining: 4.97s
# 143:	learn: 0.2714193	total: 2s	remaining: 4.95s
# 144:	learn: 0.2711292	total: 2.02s	remaining: 4.93s
# 145:	learn: 0.2706971	total: 2.03s	remaining: 4.92s
# 146:	learn: 0.2703591	total: 2.04s	remaining: 4.9s
# 147:	learn: 0.2699487	total: 2.05s	remaining: 4.88s
# 148:	learn: 0.2694808	total: 2.06s	remaining: 4.87s
# 149:	learn: 0.2690454	total: 2.08s	remaining: 4.85s
# 150:	learn: 0.2686067	total: 2.1s	remaining: 4.84s
# 151:	learn: 0.2681666	total: 2.11s	remaining: 4.83s
# 152:	learn: 0.2677790	total: 2.13s	remaining: 4.82s
# 153:	learn: 0.2674543	total: 2.14s	remaining: 4.81s
# 154:	learn: 0.2671063	total: 2.15s	remaining: 4.79s
# 155:	learn: 0.2667349	total: 2.17s	remaining: 4.78s
# 156:	learn: 0.2663217	total: 2.18s	remaining: 4.77s
# 157:	learn: 0.2660882	total: 2.2s	remaining: 4.76s
# 158:	learn: 0.2657241	total: 2.21s	remaining: 4.75s
# 159:	learn: 0.2654053	total: 2.23s	remaining: 4.74s
# 160:	learn: 0.2650001	total: 2.24s	remaining: 4.72s
# 161:	learn: 0.2647170	total: 2.25s	remaining: 4.71s
# 162:	learn: 0.2643164	total: 2.27s	remaining: 4.69s
# 163:	learn: 0.2640928	total: 2.28s	remaining: 4.67s
# 164:	learn: 0.2637985	total: 2.3s	remaining: 4.67s
# 165:	learn: 0.2634144	total: 2.32s	remaining: 4.66s
# 166:	learn: 0.2631205	total: 2.33s	remaining: 4.65s
# 167:	learn: 0.2628293	total: 2.35s	remaining: 4.64s
# 168:	learn: 0.2624797	total: 2.37s	remaining: 4.63s
# 169:	learn: 0.2621954	total: 2.38s	remaining: 4.62s
# 170:	learn: 0.2619532	total: 2.4s	remaining: 4.62s
# 171:	learn: 0.2616956	total: 2.42s	remaining: 4.61s
# 172:	learn: 0.2613927	total: 2.43s	remaining: 4.6s
# 173:	learn: 0.2611782	total: 2.45s	remaining: 4.58s
# 174:	learn: 0.2609227	total: 2.46s	remaining: 4.57s
# 175:	learn: 0.2606156	total: 2.48s	remaining: 4.56s
# 176:	learn: 0.2603630	total: 2.49s	remaining: 4.55s
# 177:	learn: 0.2600971	total: 2.51s	remaining: 4.54s
# 178:	learn: 0.2599050	total: 2.52s	remaining: 4.52s
# 179:	learn: 0.2596483	total: 2.54s	remaining: 4.51s
# 180:	learn: 0.2594280	total: 2.55s	remaining: 4.49s
# 181:	learn: 0.2592167	total: 2.56s	remaining: 4.48s
# 182:	learn: 0.2589862	total: 2.58s	remaining: 4.47s
# 183:	learn: 0.2587405	total: 2.6s	remaining: 4.46s
# 184:	learn: 0.2584745	total: 2.61s	remaining: 4.45s
# 185:	learn: 0.2583038	total: 2.63s	remaining: 4.44s
# 186:	learn: 0.2580477	total: 2.64s	remaining: 4.43s
# 187:	learn: 0.2578498	total: 2.66s	remaining: 4.42s
# 188:	learn: 0.2575814	total: 2.68s	remaining: 4.41s
# 189:	learn: 0.2572955	total: 2.7s	remaining: 4.4s
# 190:	learn: 0.2571363	total: 2.71s	remaining: 4.39s
# 191:	learn: 0.2569549	total: 2.73s	remaining: 4.38s
# 192:	learn: 0.2567361	total: 2.74s	remaining: 4.36s
# 193:	learn: 0.2565784	total: 2.75s	remaining: 4.34s
# 194:	learn: 0.2563639	total: 2.77s	remaining: 4.33s
# 195:	learn: 0.2561430	total: 2.79s	remaining: 4.32s
# 196:	learn: 0.2559069	total: 2.8s	remaining: 4.31s
# 197:	learn: 0.2556620	total: 2.82s	remaining: 4.3s
# 198:	learn: 0.2554512	total: 2.83s	remaining: 4.29s
# 199:	learn: 0.2552513	total: 2.85s	remaining: 4.28s
# 200:	learn: 0.2550413	total: 2.87s	remaining: 4.26s
# 201:	learn: 0.2548695	total: 2.88s	remaining: 4.25s
# 202:	learn: 0.2546365	total: 2.9s	remaining: 4.25s
# 203:	learn: 0.2544926	total: 2.92s	remaining: 4.23s
# 204:	learn: 0.2542992	total: 2.94s	remaining: 4.22s
# 205:	learn: 0.2541287	total: 2.95s	remaining: 4.21s
# 206:	learn: 0.2539878	total: 2.97s	remaining: 4.2s
# 207:	learn: 0.2538609	total: 2.98s	remaining: 4.19s
# 208:	learn: 0.2536954	total: 3s	remaining: 4.18s
# 209:	learn: 0.2535851	total: 3.02s	remaining: 4.17s
# 210:	learn: 0.2534079	total: 3.03s	remaining: 4.16s
# 211:	learn: 0.2532895	total: 3.05s	remaining: 4.14s
# 212:	learn: 0.2531352	total: 3.06s	remaining: 4.13s
# 213:	learn: 0.2529128	total: 3.08s	remaining: 4.11s
# 214:	learn: 0.2527289	total: 3.09s	remaining: 4.09s
# 215:	learn: 0.2525208	total: 3.1s	remaining: 4.07s
# 216:	learn: 0.2523976	total: 3.11s	remaining: 4.05s
# 217:	learn: 0.2521829	total: 3.12s	remaining: 4.03s
# 218:	learn: 0.2520246	total: 3.13s	remaining: 4.01s
# 219:	learn: 0.2518939	total: 3.13s	remaining: 3.99s
# 220:	learn: 0.2517362	total: 3.15s	remaining: 3.97s
# 221:	learn: 0.2515535	total: 3.16s	remaining: 3.96s
# 222:	learn: 0.2513237	total: 3.17s	remaining: 3.94s
# 223:	learn: 0.2511977	total: 3.18s	remaining: 3.92s
# 224:	learn: 0.2510709	total: 3.19s	remaining: 3.9s
# 225:	learn: 0.2509416	total: 3.2s	remaining: 3.88s
# 226:	learn: 0.2508031	total: 3.21s	remaining: 3.87s
# 227:	learn: 0.2506176	total: 3.23s	remaining: 3.85s
# 228:	learn: 0.2505031	total: 3.24s	remaining: 3.83s
# 229:	learn: 0.2503678	total: 3.25s	remaining: 3.81s
# 230:	learn: 0.2502469	total: 3.26s	remaining: 3.79s
# 231:	learn: 0.2500895	total: 3.27s	remaining: 3.78s
# 232:	learn: 0.2499424	total: 3.28s	remaining: 3.76s
# 233:	learn: 0.2497880	total: 3.29s	remaining: 3.74s
# 234:	learn: 0.2496291	total: 3.3s	remaining: 3.72s
# 235:	learn: 0.2495222	total: 3.31s	remaining: 3.7s
# 236:	learn: 0.2494036	total: 3.32s	remaining: 3.68s
# 237:	learn: 0.2492638	total: 3.33s	remaining: 3.66s
# 238:	learn: 0.2491347	total: 3.34s	remaining: 3.65s
# 239:	learn: 0.2490039	total: 3.35s	remaining: 3.63s
# 240:	learn: 0.2488556	total: 3.37s	remaining: 3.62s
# 241:	learn: 0.2487150	total: 3.38s	remaining: 3.61s
# 242:	learn: 0.2485687	total: 3.4s	remaining: 3.59s
# 243:	learn: 0.2483726	total: 3.41s	remaining: 3.58s
# 244:	learn: 0.2482825	total: 3.42s	remaining: 3.56s
# 245:	learn: 0.2481629	total: 3.44s	remaining: 3.55s
# 246:	learn: 0.2480616	total: 3.46s	remaining: 3.54s
# 247:	learn: 0.2479562	total: 3.47s	remaining: 3.53s
# 248:	learn: 0.2478376	total: 3.49s	remaining: 3.51s
# 249:	learn: 0.2477310	total: 3.5s	remaining: 3.5s
# 250:	learn: 0.2475749	total: 3.52s	remaining: 3.49s
# 251:	learn: 0.2474328	total: 3.53s	remaining: 3.48s
# 252:	learn: 0.2473334	total: 3.55s	remaining: 3.47s
# 253:	learn: 0.2472400	total: 3.57s	remaining: 3.46s
# 254:	learn: 0.2471423	total: 3.59s	remaining: 3.45s
# 255:	learn: 0.2470278	total: 3.61s	remaining: 3.44s
# 256:	learn: 0.2469367	total: 3.62s	remaining: 3.42s
# 257:	learn: 0.2468318	total: 3.64s	remaining: 3.41s
# 258:	learn: 0.2467409	total: 3.66s	remaining: 3.4s
# 259:	learn: 0.2466179	total: 3.67s	remaining: 3.39s
# 260:	learn: 0.2465003	total: 3.69s	remaining: 3.38s
# 261:	learn: 0.2464103	total: 3.7s	remaining: 3.36s
# 262:	learn: 0.2463141	total: 3.71s	remaining: 3.34s
# 263:	learn: 0.2462222	total: 3.72s	remaining: 3.32s
# 264:	learn: 0.2461088	total: 3.73s	remaining: 3.3s
# 265:	learn: 0.2460005	total: 3.73s	remaining: 3.29s
# 266:	learn: 0.2459238	total: 3.75s	remaining: 3.27s
# 267:	learn: 0.2458601	total: 3.76s	remaining: 3.25s
# 268:	learn: 0.2457263	total: 3.77s	remaining: 3.24s
# 269:	learn: 0.2455734	total: 3.79s	remaining: 3.23s
# 270:	learn: 0.2454888	total: 3.81s	remaining: 3.21s
# 271:	learn: 0.2453829	total: 3.82s	remaining: 3.2s
# 272:	learn: 0.2452691	total: 3.84s	remaining: 3.19s
# 273:	learn: 0.2451496	total: 3.85s	remaining: 3.18s
# 274:	learn: 0.2450593	total: 3.87s	remaining: 3.17s
# 275:	learn: 0.2449624	total: 3.88s	remaining: 3.15s
# 276:	learn: 0.2448783	total: 3.9s	remaining: 3.14s
# 277:	learn: 0.2447618	total: 3.92s	remaining: 3.13s
# 278:	learn: 0.2446542	total: 3.93s	remaining: 3.12s
# 279:	learn: 0.2445495	total: 3.95s	remaining: 3.11s
# 280:	learn: 0.2444431	total: 3.97s	remaining: 3.09s
# 281:	learn: 0.2443765	total: 3.99s	remaining: 3.08s
# 282:	learn: 0.2442897	total: 4s	remaining: 3.07s
# 283:	learn: 0.2441892	total: 4.02s	remaining: 3.06s
# 284:	learn: 0.2440698	total: 4.03s	remaining: 3.04s
# 285:	learn: 0.2439641	total: 4.05s	remaining: 3.03s
# 286:	learn: 0.2438298	total: 4.06s	remaining: 3.01s
# 287:	learn: 0.2437222	total: 4.07s	remaining: 2.99s
# 288:	learn: 0.2436476	total: 4.08s	remaining: 2.98s
# 289:	learn: 0.2435544	total: 4.09s	remaining: 2.96s
# 290:	learn: 0.2434693	total: 4.11s	remaining: 2.95s
# 291:	learn: 0.2433796	total: 4.13s	remaining: 2.94s
# 292:	learn: 0.2433053	total: 4.14s	remaining: 2.93s
# 293:	learn: 0.2432312	total: 4.16s	remaining: 2.92s
# 294:	learn: 0.2431605	total: 4.18s	remaining: 2.9s
# 295:	learn: 0.2430948	total: 4.19s	remaining: 2.89s
# 296:	learn: 0.2429808	total: 4.21s	remaining: 2.88s
# 297:	learn: 0.2428538	total: 4.23s	remaining: 2.87s
# 298:	learn: 0.2427985	total: 4.25s	remaining: 2.85s
# 299:	learn: 0.2427512	total: 4.26s	remaining: 2.84s
# 300:	learn: 0.2426964	total: 4.28s	remaining: 2.83s
# 301:	learn: 0.2426021	total: 4.29s	remaining: 2.82s
# 302:	learn: 0.2425297	total: 4.31s	remaining: 2.8s
# 303:	learn: 0.2424699	total: 4.33s	remaining: 2.79s
# 304:	learn: 0.2423803	total: 4.34s	remaining: 2.78s
# 305:	learn: 0.2423103	total: 4.36s	remaining: 2.77s
# 306:	learn: 0.2422467	total: 4.38s	remaining: 2.75s
# 307:	learn: 0.2421350	total: 4.39s	remaining: 2.74s
# 308:	learn: 0.2420683	total: 4.41s	remaining: 2.73s
# 309:	learn: 0.2419898	total: 4.43s	remaining: 2.71s
# 310:	learn: 0.2419276	total: 4.45s	remaining: 2.7s
# 311:	learn: 0.2418796	total: 4.46s	remaining: 2.69s
# 312:	learn: 0.2418271	total: 4.48s	remaining: 2.68s
# 313:	learn: 0.2417342	total: 4.5s	remaining: 2.66s
# 314:	learn: 0.2416803	total: 4.51s	remaining: 2.65s
# 315:	learn: 0.2416063	total: 4.52s	remaining: 2.63s
# 316:	learn: 0.2415115	total: 4.53s	remaining: 2.62s
# 317:	learn: 0.2414521	total: 4.55s	remaining: 2.6s
# 318:	learn: 0.2413870	total: 4.56s	remaining: 2.59s
# 319:	learn: 0.2412936	total: 4.57s	remaining: 2.57s
# 320:	learn: 0.2412089	total: 4.59s	remaining: 2.56s
# 321:	learn: 0.2411371	total: 4.61s	remaining: 2.54s
# 322:	learn: 0.2410544	total: 4.62s	remaining: 2.53s
# 323:	learn: 0.2409560	total: 4.64s	remaining: 2.52s
# 324:	learn: 0.2408806	total: 4.66s	remaining: 2.51s
# 325:	learn: 0.2407927	total: 4.67s	remaining: 2.5s
# 326:	learn: 0.2406865	total: 4.69s	remaining: 2.48s
# 327:	learn: 0.2405899	total: 4.7s	remaining: 2.46s
# 328:	learn: 0.2405244	total: 4.71s	remaining: 2.44s
# 329:	learn: 0.2404839	total: 4.72s	remaining: 2.43s
# 330:	learn: 0.2404243	total: 4.73s	remaining: 2.42s
# 331:	learn: 0.2403409	total: 4.75s	remaining: 2.4s
# 332:	learn: 0.2402721	total: 4.76s	remaining: 2.39s
# 333:	learn: 0.2401970	total: 4.78s	remaining: 2.38s
# 334:	learn: 0.2401591	total: 4.79s	remaining: 2.36s
# 335:	learn: 0.2400905	total: 4.8s	remaining: 2.35s
# 336:	learn: 0.2400291	total: 4.82s	remaining: 2.33s
# 337:	learn: 0.2399359	total: 4.83s	remaining: 2.32s
# 338:	learn: 0.2398702	total: 4.85s	remaining: 2.3s
# 339:	learn: 0.2398249	total: 4.86s	remaining: 2.29s
# 340:	learn: 0.2397551	total: 4.88s	remaining: 2.27s
# 341:	learn: 0.2396800	total: 4.89s	remaining: 2.26s
# 342:	learn: 0.2396078	total: 4.91s	remaining: 2.25s
# 343:	learn: 0.2395312	total: 4.92s	remaining: 2.23s
# 344:	learn: 0.2394399	total: 4.93s	remaining: 2.22s
# 345:	learn: 0.2393867	total: 4.95s	remaining: 2.2s
# 346:	learn: 0.2393213	total: 4.96s	remaining: 2.19s
# 347:	learn: 0.2392763	total: 4.98s	remaining: 2.17s
# 348:	learn: 0.2392235	total: 4.99s	remaining: 2.16s
# 349:	learn: 0.2391436	total: 5s	remaining: 2.14s
# 350:	learn: 0.2390735	total: 5.01s	remaining: 2.13s
# 351:	learn: 0.2390046	total: 5.03s	remaining: 2.11s
# 352:	learn: 0.2389107	total: 5.04s	remaining: 2.1s
# 353:	learn: 0.2388332	total: 5.06s	remaining: 2.09s
# 354:	learn: 0.2387542	total: 5.07s	remaining: 2.07s
# 355:	learn: 0.2386821	total: 5.08s	remaining: 2.06s
# 356:	learn: 0.2386440	total: 5.1s	remaining: 2.04s
# 357:	learn: 0.2385902	total: 5.12s	remaining: 2.03s
# 358:	learn: 0.2385389	total: 5.13s	remaining: 2.02s
# 359:	learn: 0.2384885	total: 5.15s	remaining: 2s
# 360:	learn: 0.2384366	total: 5.17s	remaining: 1.99s
# 361:	learn: 0.2383841	total: 5.2s	remaining: 1.98s
# 362:	learn: 0.2383211	total: 5.22s	remaining: 1.97s
# 363:	learn: 0.2382903	total: 5.23s	remaining: 1.96s
# 364:	learn: 0.2382441	total: 5.25s	remaining: 1.94s
# 365:	learn: 0.2381881	total: 5.27s	remaining: 1.93s
# 366:	learn: 0.2381274	total: 5.29s	remaining: 1.92s
# 367:	learn: 0.2380736	total: 5.3s	remaining: 1.9s
# 368:	learn: 0.2380170	total: 5.32s	remaining: 1.89s
# 369:	learn: 0.2379666	total: 5.33s	remaining: 1.87s
# 370:	learn: 0.2379244	total: 5.35s	remaining: 1.86s
# 371:	learn: 0.2378713	total: 5.36s	remaining: 1.84s
# 372:	learn: 0.2378492	total: 5.38s	remaining: 1.83s
# 373:	learn: 0.2378034	total: 5.39s	remaining: 1.82s
# 374:	learn: 0.2377298	total: 5.41s	remaining: 1.8s
# 375:	learn: 0.2376651	total: 5.42s	remaining: 1.79s
# 376:	learn: 0.2376194	total: 5.44s	remaining: 1.77s
# 377:	learn: 0.2375305	total: 5.45s	remaining: 1.76s
# 378:	learn: 0.2374846	total: 5.47s	remaining: 1.75s
# 379:	learn: 0.2374082	total: 5.48s	remaining: 1.73s
# 380:	learn: 0.2373738	total: 5.5s	remaining: 1.72s
# 381:	learn: 0.2373266	total: 5.52s	remaining: 1.71s
# 382:	learn: 0.2372682	total: 5.54s	remaining: 1.69s
# 383:	learn: 0.2372249	total: 5.56s	remaining: 1.68s
# 384:	learn: 0.2371690	total: 5.57s	remaining: 1.66s
# 385:	learn: 0.2370919	total: 5.59s	remaining: 1.65s
# 386:	learn: 0.2370531	total: 5.61s	remaining: 1.64s
# 387:	learn: 0.2369991	total: 5.62s	remaining: 1.62s
# 388:	learn: 0.2369391	total: 5.64s	remaining: 1.61s
# 389:	learn: 0.2368798	total: 5.66s	remaining: 1.59s
# 390:	learn: 0.2368335	total: 5.67s	remaining: 1.58s
# 391:	learn: 0.2367793	total: 5.68s	remaining: 1.56s
# 392:	learn: 0.2367225	total: 5.7s	remaining: 1.55s
# 393:	learn: 0.2366758	total: 5.71s	remaining: 1.53s
# 394:	learn: 0.2366391	total: 5.74s	remaining: 1.52s
# 395:	learn: 0.2365936	total: 5.75s	remaining: 1.51s
# 396:	learn: 0.2365359	total: 5.77s	remaining: 1.5s
# 397:	learn: 0.2364987	total: 5.79s	remaining: 1.48s
# 398:	learn: 0.2364517	total: 5.8s	remaining: 1.47s
# 399:	learn: 0.2363588	total: 5.82s	remaining: 1.46s
# 400:	learn: 0.2363248	total: 5.84s	remaining: 1.44s
# 401:	learn: 0.2362769	total: 5.86s	remaining: 1.43s
# 402:	learn: 0.2361919	total: 5.87s	remaining: 1.41s
# 403:	learn: 0.2361154	total: 5.89s	remaining: 1.4s
# 404:	learn: 0.2360751	total: 5.91s	remaining: 1.39s
# 405:	learn: 0.2360304	total: 5.92s	remaining: 1.37s
# 406:	learn: 0.2359873	total: 5.94s	remaining: 1.36s
# 407:	learn: 0.2359327	total: 5.96s	remaining: 1.34s
# 408:	learn: 0.2358804	total: 5.97s	remaining: 1.33s
# 409:	learn: 0.2358312	total: 5.98s	remaining: 1.31s
# 410:	learn: 0.2357874	total: 5.99s	remaining: 1.3s
# 411:	learn: 0.2357575	total: 6s	remaining: 1.28s
# 412:	learn: 0.2356975	total: 6.01s	remaining: 1.27s
# 413:	learn: 0.2356725	total: 6.02s	remaining: 1.25s
# 414:	learn: 0.2356062	total: 6.03s	remaining: 1.24s
# 415:	learn: 0.2355691	total: 6.04s	remaining: 1.22s
# 416:	learn: 0.2354970	total: 6.05s	remaining: 1.2s
# 417:	learn: 0.2354575	total: 6.06s	remaining: 1.19s
# 418:	learn: 0.2354039	total: 6.07s	remaining: 1.17s
# 419:	learn: 0.2353590	total: 6.08s	remaining: 1.16s
# 420:	learn: 0.2353196	total: 6.09s	remaining: 1.14s
# 421:	learn: 0.2352832	total: 6.1s	remaining: 1.13s
# 422:	learn: 0.2352263	total: 6.11s	remaining: 1.11s
# 423:	learn: 0.2351862	total: 6.12s	remaining: 1.1s
# 424:	learn: 0.2351389	total: 6.13s	remaining: 1.08s
# 425:	learn: 0.2350814	total: 6.14s	remaining: 1.07s
# 426:	learn: 0.2350428	total: 6.16s	remaining: 1.05s
# 427:	learn: 0.2350036	total: 6.17s	remaining: 1.04s
# 428:	learn: 0.2349599	total: 6.18s	remaining: 1.02s
# 429:	learn: 0.2349182	total: 6.19s	remaining: 1.01s
# 430:	learn: 0.2348520	total: 6.2s	remaining: 993ms
# 431:	learn: 0.2347877	total: 6.21s	remaining: 978ms
# 432:	learn: 0.2347221	total: 6.23s	remaining: 964ms
# 433:	learn: 0.2346734	total: 6.24s	remaining: 949ms
# 434:	learn: 0.2346116	total: 6.25s	remaining: 934ms
# 435:	learn: 0.2345669	total: 6.26s	remaining: 919ms
# 436:	learn: 0.2345108	total: 6.27s	remaining: 904ms
# 437:	learn: 0.2344775	total: 6.28s	remaining: 889ms
# 438:	learn: 0.2344314	total: 6.29s	remaining: 874ms
# 439:	learn: 0.2343906	total: 6.3s	remaining: 859ms
# 440:	learn: 0.2343491	total: 6.31s	remaining: 844ms
# 441:	learn: 0.2343082	total: 6.32s	remaining: 829ms
# 442:	learn: 0.2342566	total: 6.33s	remaining: 814ms
# 443:	learn: 0.2342168	total: 6.34s	remaining: 799ms
# 444:	learn: 0.2341548	total: 6.35s	remaining: 785ms
# 445:	learn: 0.2340813	total: 6.36s	remaining: 770ms
# 446:	learn: 0.2340444	total: 6.37s	remaining: 755ms
# 447:	learn: 0.2340009	total: 6.38s	remaining: 740ms
# 448:	learn: 0.2339422	total: 6.39s	remaining: 726ms
# 449:	learn: 0.2338989	total: 6.4s	remaining: 711ms
# 450:	learn: 0.2338738	total: 6.41s	remaining: 696ms
# 451:	learn: 0.2338401	total: 6.42s	remaining: 682ms
# 452:	learn: 0.2337969	total: 6.43s	remaining: 668ms
# 453:	learn: 0.2337732	total: 6.45s	remaining: 653ms
# 454:	learn: 0.2337246	total: 6.46s	remaining: 639ms
# 455:	learn: 0.2336823	total: 6.47s	remaining: 625ms
# 456:	learn: 0.2336473	total: 6.49s	remaining: 610ms
# 457:	learn: 0.2336263	total: 6.5s	remaining: 596ms
# 458:	learn: 0.2335815	total: 6.51s	remaining: 582ms
# 459:	learn: 0.2335382	total: 6.54s	remaining: 568ms
# 460:	learn: 0.2335111	total: 6.58s	remaining: 556ms
# 461:	learn: 0.2334742	total: 6.6s	remaining: 543ms
# 462:	learn: 0.2334355	total: 6.61s	remaining: 528ms
# 463:	learn: 0.2334083	total: 6.62s	remaining: 514ms
# 464:	learn: 0.2333611	total: 6.63s	remaining: 499ms
# 465:	learn: 0.2333304	total: 6.64s	remaining: 484ms
# 466:	learn: 0.2332869	total: 6.65s	remaining: 470ms
# 467:	learn: 0.2332501	total: 6.66s	remaining: 455ms
# 468:	learn: 0.2332110	total: 6.67s	remaining: 441ms
# 469:	learn: 0.2331311	total: 6.68s	remaining: 426ms
# 470:	learn: 0.2330879	total: 6.69s	remaining: 412ms
# 471:	learn: 0.2330249	total: 6.7s	remaining: 398ms
# 472:	learn: 0.2329819	total: 6.71s	remaining: 383ms
# 473:	learn: 0.2329444	total: 6.73s	remaining: 369ms
# 474:	learn: 0.2329022	total: 6.74s	remaining: 355ms
# 475:	learn: 0.2328628	total: 6.75s	remaining: 341ms
# 476:	learn: 0.2328189	total: 6.77s	remaining: 326ms
# 477:	learn: 0.2327809	total: 6.78s	remaining: 312ms
# 478:	learn: 0.2327309	total: 6.79s	remaining: 298ms
# 479:	learn: 0.2327064	total: 6.81s	remaining: 284ms
# 480:	learn: 0.2326555	total: 6.82s	remaining: 269ms
# 481:	learn: 0.2326147	total: 6.83s	remaining: 255ms
# 482:	learn: 0.2325697	total: 6.84s	remaining: 241ms
# 483:	learn: 0.2325314	total: 6.85s	remaining: 227ms
# 484:	learn: 0.2325033	total: 6.87s	remaining: 212ms
# 485:	learn: 0.2324741	total: 6.88s	remaining: 198ms
# 486:	learn: 0.2324217	total: 6.89s	remaining: 184ms
# 487:	learn: 0.2323978	total: 6.9s	remaining: 170ms
# 488:	learn: 0.2323693	total: 6.91s	remaining: 155ms
# 489:	learn: 0.2323203	total: 6.92s	remaining: 141ms
# 490:	learn: 0.2322816	total: 6.94s	remaining: 127ms
# 491:	learn: 0.2322551	total: 6.96s	remaining: 113ms
# 492:	learn: 0.2322188	total: 6.97s	remaining: 99ms
# 493:	learn: 0.2321745	total: 6.99s	remaining: 84.9ms
# 494:	learn: 0.2321490	total: 7s	remaining: 70.7ms
# 495:	learn: 0.2321141	total: 7.02s	remaining: 56.6ms
# 496:	learn: 0.2320888	total: 7.03s	remaining: 42.5ms
# 497:	learn: 0.2320569	total: 7.05s	remaining: 28.3ms
# 498:	learn: 0.2320095	total: 7.06s	remaining: 14.1ms
# 499:	learn: 0.2319726	total: 7.07s	remaining: 0us
# ROC_AUC: 0.6951086956521739
#
# Confusion_metrix (0.1 Threshold):
#  [[348 112]
#  [ 20  20]]
# Precision (0.1 Threshold):  0.15151515151515152
# Recall (0.1 Threshold):  0.5
# F1-score ( 0.1 Threshold): 0.23255813953488375
#
# Cohen_kappa (0.1 Threshold):  0.12513255567338277
